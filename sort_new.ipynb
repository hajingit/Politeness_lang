# %%
from politeness.test_documents import TEST_DOCUMENTS, TEST_TEXTS
from politeness.api_util import get_scores_strategies_token_indices

#for text in TEST_TEXTS:

import numpy as np
import pandas as pd
import json

df = pd.read_csv("pol600withlabel.csv", encoding="utf-8")

# %%
print(get_scores_strategies_token_indices("text"))
# Out:
# {'score_polite': 0.43900741852254699, 'score_impolite': 0.5609925814774529, 'strategies': [], 'sentences': [{'tokens': ['text'], 'involved_index': set(), 'impolite_index': set(), 'polite_index': []}]}

# %%
df
# Out:
#      Community   Num  Index      Id  \
# 0    Wikipedia     1      0  448758
# 1    Wikipedia     2      1  367359
# 2    Wikipedia     3      2  622653
# 3    Wikipedia     4      3  350825
# 4    Wikipedia     5      4  348828
# 5    Wikipedia     6      5     143
# 6    Wikipedia     7      6  297566
# 7    Wikipedia     8      7  550560
# 8    Wikipedia     9      8  354110
# 9    Wikipedia    10      9  622398
# 10   Wikipedia    11     10  521809
# 11   Wikipedia    12     11  388839
# 12   Wikipedia    13     12  206259
# 13   Wikipedia    14     13  394910
# 14   Wikipedia    15     14  620687
# 15   Wikipedia    16     15  506658
# 16   Wikipedia    17     16  488272
# 17   Wikipedia    18     17  237849
# 18   Wikipedia    19     18  555289
# 19   Wikipedia    20     19  622922
# 20   Wikipedia    21     20  342386
# 21   Wikipedia    22     21  446216
# 22   Wikipedia    23     22  208007
# 23   Wikipedia    24     23  109408
# 24   Wikipedia    25     24  390848
# 25   Wikipedia    26     25  623298
# 26   Wikipedia    27     26   34843
# 27   Wikipedia    28     27  241254
# 28   Wikipedia    29     28   21906
# 29   Wikipedia    30     29  629684
# ..         ...   ...    ...     ...
# 570  Wikipedia  1271    570  624965
# 571  Wikipedia  1272    571  625066
# 572  Wikipedia  1273    572  625077
# 573  Wikipedia  1274    573  625120
# 574  Wikipedia  1275    574  625156
# 575  Wikipedia  1276    575  625706
# 576  Wikipedia  1277    576  625793
# 577  Wikipedia  1278    577  625993
# 578  Wikipedia  1279    578  626078
# 579  Wikipedia  1280    579  626199
# 580  Wikipedia  1281    580  626505
# 581  Wikipedia  1282    581  626949
# 582  Wikipedia  1283    582  626970
# 583  Wikipedia  1284    583  627166
# 584  Wikipedia  1285    584  627410
# 585  Wikipedia  1286    585  627434
# 586  Wikipedia  1287    586  627441
# 587  Wikipedia  1288    587  627547
# 588  Wikipedia  1289    588  627968
# 589  Wikipedia  1290    589  628136
# 590  Wikipedia  1291    590  628362
# 591  Wikipedia  1292    591  628398
# 592  Wikipedia  1293    592  628721
# 593  Wikipedia  1294    593  628742
# 594  Wikipedia  1295    594  629553
# 595  Wikipedia  1296    595  629728
# 596  Wikipedia  1297    596  629786
# 597  Wikipedia  1298    597  630132
# 598  Wikipedia  1299    598  630525
# 599  Wikipedia  1300    599  630746
#
#                                                Request   EN1   EN2  EN3  EN4  \
# 0    Answered at <url>. Maybe you are not familiar ... -10.0   NaN  NaN  NaN
# 1    Btw, ignoring the London stations it looks lik...  -7.0   NaN  NaN  NaN
# 2    Because Wikipedia is an encylopaedia not a fre... -12.0   NaN  NaN  NaN
# 3    "''Images with iconic status or historical imp... -12.0   NaN  NaN  NaN
# 4    May I also ask how CheckUser became involved i... -11.0   NaN  NaN  NaN
# 5    Good work on the canal junctions! Where approp...   7.0   NaN  NaN  NaN
# 6             What is a wall these days? 10 sentences?   0.0   NaN  NaN  NaN
# 7    I see a "remove protection" tab on the <url>, ...   4.0   NaN  NaN  NaN
# 8    Why delete the page <url> with no explanation,... -12.0   NaN  NaN  NaN
# 9    Thanks a ton for looking that up for me. For t...   9.0   NaN  NaN  NaN
# 10                               Is this okay? Or OTT?   NaN   NaN  NaN  NaN
# 11   Hi, <name>, I was just wondering why you did <...   NaN   3.0  NaN  NaN
# 12   Also, both <url> and <url> wikilink "hiatus", ...   NaN   1.0  NaN  NaN
# 13   I am puzzled by your "fixing" of the recursion...   NaN  -3.0  NaN  NaN
# 14   That's "fucking consistent naming-schemers", p...   NaN -12.0  NaN  NaN
# 15   Hey <name> I have a quick question - do you do...   NaN   5.0  NaN  NaN
# 16   Nothing messed up from where I'm sitting. What...   NaN   5.0  NaN  NaN
# 17   Regarding <url>, <url> says not to redlink in ...   NaN   4.0  NaN  NaN
# 18   I was thinking on it, but one question: I see ...   NaN   5.0  NaN  NaN
# 19   That is weird. What happens if you create Usor...   NaN   7.0  NaN  NaN
# 20   I think we're going to just have to agree to d...   NaN   NaN  NaN  NaN
# 21   Thanks for the redirect help! Is that somethin...   NaN   NaN  NaN  NaN
# 22   Do You have the list of other flag bearers fro...   NaN   NaN  NaN  NaN
# 23   It is being suggested on <url> that the recent...   NaN   NaN  NaN  NaN
# 24   Looking at Kotorkid's contributions on <url>, ...   NaN   NaN  NaN  NaN
# 25   As another aside, they are mostly Germans. Wha...   NaN   NaN  NaN  NaN
# 26   The profile seems good as it is. Why don't we ...   NaN   NaN  NaN  NaN
# 27   US national defense for the twenty-first centu...   NaN   NaN  NaN  NaN
# 28   what do you think was the purpose of this Fess...   NaN   NaN  NaN  NaN
# 29   Out of curiosity what are you testing? How are...   NaN   NaN  NaN  NaN
# ..                                                 ...   ...   ...  ...  ...
# 570  Do you feel that you've had success in forming...   1.0  -9.0  0.0  1.0
# 571  Oosterman is hardly the world's foremost exper... -10.0  -6.0  2.0  0.0
# 572  I tried to create a similar map for Canada but...  11.0  -2.0  1.0  1.0
# 573  Hey, if you took this picture you can release ...   4.0   3.0  2.0  0.0
# 574  Evidently, I don't have enough consciousness, ...  -2.0 -10.0 -7.0 -1.0
# 575  Hi, I made on comment on the image page about ...   4.0  -1.0 -2.0  NaN
# 576  There's nothing in your history besides editin...  -1.0  -4.0 -1.0  0.0
# 577  Bingo!  Since you've seen the light, now will ... -11.0  -9.0 -1.0 -2.0
# 578  Your bot's edits aren't being marked as such; ...  -3.0  -4.0  0.0  0.0
# 579  Just curious... Where did it come from?  Where...   4.0  -9.0 -3.0  0.0
# 580  Perfect, thank you! Can you help with the phon...   8.0   4.0  1.0  2.0
# 581  So far there are four editors on 'url' who hav...  -5.0  -8.0 -3.0 -6.0
# 582  If it's not clear, I am asking for a '''quote ... -11.0  -4.0  1.0  0.0
# 583  That sounds fine, but why would you want someb...  -8.0  -6.0  0.0  0.0
# 584  So the nomination was made by your sock. Could...   3.0 -10.0  2.0  0.0
# 585  I see that you have made an edit to another pa...   5.0  -1.0  0.0  1.0
# 586  And wasting our time as well. I can only repea... -11.0 -10.0 -5.0 -7.0
# 587  Your first attempt at doing this also added a ...  -3.0  -5.0  1.0  1.0
# 588  Hi Steph - this would be a fine article, but i...  12.0   1.0  0.0  1.0
# 589  Okay, how about this... Give me five minutes. ...  -1.0  -6.0  1.0 -2.0
# 590  Do you really think it is necessary to do that...  -7.0  -6.0 -3.0 -3.0
# 591  Have you as yet cast your own vote for 'url'? ...  10.0  -4.0  2.0  0.0
# 592  Sorry for the slow reply, something I needed t...  11.0   2.0 -1.0  0.0
# 593  Thank you for telling me. Can you please rever...  13.0  -1.0 -1.0  8.0
# 594  No, I said that targetting images merely becau...  -9.0  -5.0 -3.0 -1.0
# 595  I create 'url', and then I would click "Move" ...   9.0   3.0  1.0  1.0
# 596  And NO Igor, discuss edits with ME please. Are... -11.0  -7.0 -4.0 -5.0
# 597  All allegations currently in the article shoul...   1.0   2.0  1.0  1.0
# 598  Just noticed that the "time" field is eliminat...   4.0  -1.0  0.0  1.0
# 599  Sorry, I did not know there has been a categor...   9.0   2.0  1.0 -1.0
#
#       EN5    ...      CH16_zscore  CH17_zscore  CH18_zscore  CH19_zscore  \
# 0     NaN    ...        -0.439874          NaN          NaN          NaN
# 1     NaN    ...         0.057375          NaN          NaN          NaN
# 2     NaN    ...        -0.439874          NaN          NaN          NaN
# 3     NaN    ...        -0.439874          NaN          NaN          NaN
# 4     NaN    ...         1.300498          NaN          NaN          NaN
# 5     NaN    ...         2.792246          NaN          NaN          NaN
# 6     NaN    ...        -0.191250          NaN          NaN          NaN
# 7     NaN    ...         0.057375          NaN          NaN          NaN
# 8     NaN    ...        -0.937123          NaN          NaN          NaN
# 9     NaN    ...         0.803249          NaN          NaN          NaN
# 10   -2.0    ...         0.057375          NaN          NaN          NaN
# 11   -4.0    ...         0.057375          NaN     1.393379          NaN
# 12   -2.0    ...        -0.688499          NaN    -0.268703          NaN
# 13   -6.0    ...        -0.191250          NaN    -1.723025          NaN
# 14  -11.0    ...              NaN          NaN    -2.346305          NaN
# 15    6.0    ...         0.057375          NaN     0.977858          NaN
# 16    3.0    ...        -0.688499          NaN    -0.891984          NaN
# 17   -3.0    ...        -0.688499          NaN    -1.307504          NaN
# 18   -1.0    ...         0.057375          NaN     0.354577          NaN
# 19    0.0    ...         0.057375          NaN          NaN          NaN
# 20    NaN    ...              NaN          NaN          NaN          NaN
# 21    NaN    ...              NaN          NaN          NaN          NaN
# 22    NaN    ...              NaN          NaN          NaN          NaN
# 23    NaN    ...              NaN          NaN          NaN          NaN
# 24    NaN    ...              NaN          NaN          NaN          NaN
# 25    NaN    ...              NaN          NaN          NaN          NaN
# 26    NaN    ...              NaN          NaN          NaN          NaN
# 27    NaN    ...              NaN          NaN          NaN          NaN
# 28    NaN    ...              NaN          NaN          NaN          NaN
# 29    NaN    ...              NaN          NaN          NaN          NaN
# ..    ...    ...              ...          ...          ...          ...
# 570   1.0    ...              NaN          NaN          NaN          NaN
# 571   2.0    ...              NaN          NaN          NaN          NaN
# 572  -2.0    ...              NaN          NaN          NaN          NaN
# 573  -1.0    ...              NaN          NaN          NaN          NaN
# 574  -8.0    ...              NaN          NaN          NaN          NaN
# 575  -2.0    ...              NaN          NaN          NaN          NaN
# 576  -2.0    ...              NaN          NaN          NaN          NaN
# 577  -9.0    ...              NaN          NaN          NaN          NaN
# 578  -1.0    ...              NaN          NaN          NaN          NaN
# 579  -2.0    ...              NaN          NaN          NaN          NaN
# 580   4.0    ...              NaN          NaN          NaN          NaN
# 581  -8.0    ...              NaN          NaN          NaN          NaN
# 582  -4.0    ...              NaN          NaN          NaN          NaN
# 583  -6.0    ...              NaN          NaN          NaN          NaN
# 584  -8.0    ...              NaN          NaN          NaN          NaN
# 585   1.0    ...              NaN          NaN          NaN          NaN
# 586 -11.0    ...              NaN          NaN          NaN          NaN
# 587   4.0    ...              NaN          NaN          NaN          NaN
# 588   4.0    ...              NaN          NaN          NaN          NaN
# 589  -8.0    ...              NaN          NaN          NaN          NaN
# 590  -8.0    ...              NaN          NaN          NaN          NaN
# 591   1.0    ...              NaN          NaN          NaN          NaN
# 592  -1.0    ...              NaN          NaN          NaN          NaN
# 593  11.0    ...              NaN          NaN          NaN          NaN
# 594   2.0    ...              NaN          NaN          NaN          NaN
# 595   2.0    ...              NaN          NaN          NaN          NaN
# 596 -11.0    ...              NaN          NaN          NaN          NaN
# 597   4.0    ...              NaN          NaN          NaN          NaN
# 598   6.0    ...              NaN          NaN          NaN          NaN
# 599   2.0    ...              NaN          NaN          NaN          NaN
#
#      CH20_zscore  CH21_zscore  label_t  label_t_z  label_d  label_d_z
# 0            NaN    -0.369412        0          0       -1         -1
# 1            NaN     0.640946        0          0       -1         -1
# 2            NaN     1.146126        0          0        1          1
# 3            NaN    -0.874592        1          1        1          1
# 4            NaN     0.893536        0          0        1          1
# 5            NaN     0.135767        0          0       -1         -1
# 6            NaN     0.388357        0          0       -1         -1
# 7            NaN     1.146126        0          0       -1         -1
# 8            NaN     0.640946        0          0       -1         -1
# 9            NaN     0.135767        0          0       -1         -1
# 10           NaN          NaN        0          0       -1         -1
# 11           NaN          NaN        0          0       -1         -1
# 12           NaN          NaN        0          0       -1         -1
# 13           NaN          NaN        0          0        0          0
# 14           NaN          NaN        0          0       -1         -1
# 15           NaN          NaN        1          1        1          1
# 16           NaN          NaN        0          0        0          0
# 17           NaN          NaN        1          0       -1         -1
# 18           NaN          NaN        0          0       -1         -1
# 19           NaN          NaN        0          0        0          0
# 20     -1.164626          NaN        1          1        1          1
# 21      2.306997          NaN        0          0       -1         -1
# 22      0.281884          NaN        0          0       -1         -1
# 23     -0.007418          NaN        0          0       -1         -1
# 24           NaN          NaN        0          0       -1         -1
# 25     -0.296720          NaN        0          0       -1         -1
# 26      1.149790          NaN        0          0        0          0
# 27     -2.611135          NaN        1          1        1          1
# 28     -2.611135          NaN        1          0        1          1
# 29     -2.611135          NaN        0          1        1          1
# ..           ...          ...      ...        ...      ...        ...
# 570          NaN          NaN        0          0       -1         -1
# 571          NaN          NaN        0          0       -1         -1
# 572          NaN          NaN        0          0       -1         -1
# 573          NaN          NaN        0          0        0          0
# 574          NaN          NaN        1          1        1          1
# 575          NaN          NaN        1          1        1          1
# 576          NaN          NaN        0          0        0          0
# 577          NaN          NaN        1          1        1          1
# 578          NaN          NaN        0          0       -1         -1
# 579          NaN          NaN        0          0       -1         -1
# 580          NaN          NaN        0          0        0          0
# 581          NaN          NaN        0          0       -1         -1
# 582          NaN          NaN        1          1        1          1
# 583          NaN          NaN        0          0       -1         -1
# 584          NaN          NaN        1          0        1          1
# 585          NaN          NaN        0          0       -1         -1
# 586          NaN          NaN        0          0       -1         -1
# 587          NaN          NaN        0          0       -1         -1
# 588          NaN          NaN        0          0       -1         -1
# 589          NaN          NaN        0          0       -1         -1
# 590          NaN          NaN        0          0       -1         -1
# 591          NaN          NaN        0          0       -1         -1
# 592          NaN          NaN        0          0       -1         -1
# 593          NaN          NaN        0          0       -1         -1
# 594          NaN          NaN        0          0        0          0
# 595          NaN          NaN        0          1       -1         -1
# 596          NaN          NaN        0          0       -1         -1
# 597          NaN          NaN        0          0       -1         -1
# 598          NaN          NaN        0          0       -1         -1
# 599          NaN          NaN        0          0        0          0
#
# [600 rows x 113 columns]

# %%
result = {}

for i, row in df.iterrows():
    Index=row["Index"]
    Num = row["Num"]
    Request = row["Request"]
    ret = get_scores_strategies_token_indices(Request)
    en_mean = np.asscalar(np.nanmean(np.array((row["EN1":"EN31"]).values, dtype=np.float32)))
    ch_mean = np.asscalar(np.nanmean(np.array((row["CH1":"CH21"]).values, dtype=np.float32)))
    en_mean_z = np.asscalar(np.nanmean(np.array((row["EN1_zscore":"EN31_zscore"]).values, dtype=np.float32)))
    ch_mean_z = np.asscalar(np.nanmean(np.array((row["CH1_zscore":"CH21_zscore"]).values, dtype=np.float32)))
    
    for s in ret["strategies"]:
        if s not in result:
            result[s] = []
            result[s].append(
                {
                    "Index":Index,
                    "Num": Num,
                    "Request": Request,
                    "en_mean": en_mean,
                    "ch_mean": ch_mean,
                    "en_mean_z":en_mean_z,
                    "ch_mean_z":ch_mean_z
                })
    if i % 20 == 0:
        print(i)

with open("sort_in_strategies_z.json", "w", encoding="utf-8") as fout:
    json.dump(result, fout)

import pprint

pprint.pprint(result)
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# {'1st person': [{'Index': 4,
#                  'Num': 5,
#                  'Request': 'May I also ask how CheckUser became involved in '
#                             'the matter? To justify such a use of computer '
#                             'records, surely someone needs to invoke a due '
#                             'process of some kind for the action to be '
#                             'justified?',
#                  'ch_mean': 3.5999999046325684,
#                  'ch_mean_z': 0.7812305688858032,
#                  'en_mean': -0.75,
#                  'en_mean_z': -0.10708987712860107}],
#  '1st person pl.': [{'Index': 5,
#                      'Num': 6,
#                      'Request': 'Good work on the canal junctions! Where '
#                                 'appropriate, do you think we should give the '
#                                 'nearest pedestrian access point, from the '
#                                 'road (as opposed to canal) network?',
#                      'ch_mean': 8.0,
#                      'ch_mean_z': 1.630479097366333,
#                      'en_mean': 7.25,
#                      'en_mean_z': 1.4962581396102905}],
#  '1st person start': [{'Index': 7,
#                        'Num': 8,
#                        'Request': 'I see a "remove protection" tab on the '
#                                   '<url>, which tells an admin that the '
#                                   'article is protected. Are you still able to '
#                                   'edit it?',
#                        'ch_mean': 3.0,
#                        'ch_mean_z': 0.6099435091018677,
#                        'en_mean': 1.625,
#                        'en_mean_z': 0.18275919556617737}],
#  '2nd person': [{'Index': 0,
#                  'Num': 1,
#                  'Request': 'Answered at <url>. Maybe you are not familiar '
#                             'with the expression?',
#                  'ch_mean': 0.20000000298023224,
#                  'ch_mean_z': -0.05805463716387749,
#                  'en_mean': -2.375,
#                  'en_mean_z': -0.5211309194564819}],
#  '2nd person start': [{'Index': 74,
#                        'Num': 75,
#                        'Request': "You're welcome. What else is peer review "
#                                   'for?',
#                        'ch_mean': 5.0,
#                        'ch_mean_z': 1.136239767074585,
#                        'en_mean': 4.888888835906982,
#                        'en_mean_z': 0.7597931623458862}],
#  'Apologizing': [{'Index': 44,
#                   'Num': 45,
#                   'Request': 'I got the page fixed. Sorry I had to do it '
#                              "several times on the page but it wouldn't let me "
#                              'revert it to before the IP user vandalized it '
#                              'how do you do that?',
#                   'ch_mean': 5.75,
#                   'ch_mean_z': 0.9748635292053223,
#                   'en_mean': 6.142857074737549,
#                   'en_mean_z': 1.043876051902771}],
#  'Deference': [{'Index': 5,
#                 'Num': 6,
#                 'Request': 'Good work on the canal junctions! Where '
#                            'appropriate, do you think we should give the '
#                            'nearest pedestrian access point, from the road (as '
#                            'opposed to canal) network?',
#                 'ch_mean': 8.0,
#                 'ch_mean_z': 1.630479097366333,
#                 'en_mean': 7.25,
#                 'en_mean_z': 1.4962581396102905}],
#  'Direct question': [{'Index': 2,
#                       'Num': 3,
#                       'Request': 'Because Wikipedia is an encylopaedia not a '
#                                  'free advertising and self promotion venue. '
#                                  'Why do you keep abusing it?',
#                       'ch_mean': -2.200000047683716,
#                       'ch_mean_z': -0.46058139204978943,
#                       'en_mean': -6.625,
#                       'en_mean_z': -1.514231562614441}],
#  'Direct start': [{'Index': 10,
#                    'Num': 11,
#                    'Request': 'Is this okay? Or OTT?',
#                    'ch_mean': -1.0,
#                    'ch_mean_z': -0.26865047216415405,
#                    'en_mean': 2.0,
#                    'en_mean_z': 0.12125283479690552}],
#  'Factuality': [{'Index': 3,
#                  'Num': 4,
#                  'Request': '"\'\'Images with iconic status or historical '
#                             'importance: As subjects of commentary.\'\'". '
#                             "Listen, it's just trivial to look up, could you "
#                             'take the care of actually reading these policies '
#                             'before arguing over them?',
#                  'ch_mean': -1.600000023841858,
#                  'ch_mean_z': -0.39751291275024414,
#                  'en_mean': -8.75,
#                  'en_mean_z': -2.00508975982666}],
#  'Gratitude': [{'Index': 9,
#                 'Num': 10,
#                 'Request': 'Thanks a ton for looking that up for me. For the '
#                            'purposes of a citation, what are the page numbers '
#                            'for the whole article?',
#                 'ch_mean': 4.599999904632568,
#                 'ch_mean_z': 0.8614376187324524,
#                 'en_mean': 7.75,
#                 'en_mean_z': 1.544495701789856}],
#  'HASHEDGE': [{'Index': 0,
#                'Num': 1,
#                'Request': 'Answered at <url>. Maybe you are not familiar with '
#                           'the expression?',
#                'ch_mean': 0.20000000298023224,
#                'ch_mean_z': -0.05805463716387749,
#                'en_mean': -2.375,
#                'en_mean_z': -0.5211309194564819}],
#  'HASNEGATIVE': [{'Index': 3,
#                   'Num': 4,
#                   'Request': '"\'\'Images with iconic status or historical '
#                              'importance: As subjects of commentary.\'\'". '
#                              "Listen, it's just trivial to look up, could you "
#                              'take the care of actually reading these policies '
#                              'before arguing over them?',
#                   'ch_mean': -1.600000023841858,
#                   'ch_mean_z': -0.39751291275024414,
#                   'en_mean': -8.75,
#                   'en_mean_z': -2.00508975982666}],
#  'HASPOSITIVE': [{'Index': 1,
#                   'Num': 2,
#                   'Request': 'Btw, ignoring the London stations it looks like '
#                              'your bot has <url>. Has this happened elsewhere?',
#                   'ch_mean': 2.0,
#                   'ch_mean_z': 0.32652217149734497,
#                   'en_mean': -1.375,
#                   'en_mean_z': -0.3502178192138672}],
#  'Hedges': [{'Index': 5,
#              'Num': 6,
#              'Request': 'Good work on the canal junctions! Where appropriate, '
#                         'do you think we should give the nearest pedestrian '
#                         'access point, from the road (as opposed to canal) '
#                         'network?',
#              'ch_mean': 8.0,
#              'ch_mean_z': 1.630479097366333,
#              'en_mean': 7.25,
#              'en_mean_z': 1.4962581396102905}],
#  'INDICATIVE': [{'Index': 45,
#                  'Num': 46,
#                  'Request': "I'm trying to keep Minority Report as a Good "
#                             'Article and the <url> requested for copyediting - '
#                             "but didn't give examples to cleanup. Can you give "
#                             'me some input on what to rewrite?',
#                  'ch_mean': 1.5,
#                  'ch_mean_z': -0.3795222043991089,
#                  'en_mean': 4.857142925262451,
#                  'en_mean_z': 0.646802544593811}],
#  'Indirect (greeting)': [{'Index': 11,
#                           'Num': 12,
#                           'Request': 'Hi, <name>, I was just wondering why you '
#                                      'did <url>. If in your opinion that text '
#                                      "shouldn't be there, why not just delete "
#                                      'it completely?',
#                           'ch_mean': 0.25,
#                           'ch_mean_z': 0.0007516741752624512,
#                           'en_mean': 0.25,
#                           'en_mean_z': -0.25934743881225586}],
#  'Please': [{'Index': 14,
#              'Num': 15,
#              'Request': 'That\'s "fucking consistent naming-schemers", please. '
#                         "Unless there's some actual reason for a) restriction "
#                         'to highways, b) infeasibly small stub categories, and '
#                         'c) inconsistent capitalisation?',
#              'ch_mean': -8.666666984558105,
#              'ch_mean_z': -1.7798858880996704,
#              'en_mean': -9.25,
#              'en_mean_z': -2.1907427310943604}],
#  'Please start': [{'Index': 210,
#                    'Num': 211,
#                    'Request': "'<url>'''Please also answer the questions at "
#                               "paragraph '''<url>''' above, as you are looking "
#                               'like a classic bully admin who abuses his '
#                               'powers and should be stripped of that role. Is '
#                               'there any review process in wikipedia, for '
#                               'proposing that you be stripped of your admin '
#                               'powers for bullyism?',
#                    'ch_mean': -1.600000023841858,
#                    'ch_mean_z': -0.47165602445602417,
#                    'en_mean': -4.111111164093018,
#                    'en_mean_z': -1.3589653968811035}],
#  'SUBJUNCTIVE': [{'Index': 3,
#                   'Num': 4,
#                   'Request': '"\'\'Images with iconic status or historical '
#                              'importance: As subjects of commentary.\'\'". '
#                              "Listen, it's just trivial to look up, could you "
#                              'take the care of actually reading these policies '
#                              'before arguing over them?',
#                   'ch_mean': -1.600000023841858,
#                   'ch_mean_z': -0.39751291275024414,
#                   'en_mean': -8.75,
#                   'en_mean_z': -2.00508975982666}]}
