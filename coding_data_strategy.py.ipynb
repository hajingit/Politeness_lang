# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("politeness_coding_data.csv", index_col = [0])

# %%
from
# Out:
#      Community      Id                                            Request  \
# ID
# 1    Wikipedia    2320  Hmm...the picture was taken on my camera by so...
# 2    Wikipedia    4026  My question is "Why?" I am doing all the citat...
# 3    Wikipedia    4767  I noticed you removed Pero Defformero from the...
# 4    Wikipedia    5692  I don't see a connection between the 'url' and...
# 5    Wikipedia    7122  url'.. it doesn't really explain what the issu...
# 6    Wikipedia   17795  Hello, Jeff79. Would you weigh in on the above...
# 7    Wikipedia   19520  Thanks for change to Hugh de Grandmesnil - I a...
# 8    Wikipedia   20833  Darkstar, I am completely baffled by this, I d...
# 9    Wikipedia   21812  These clickable images are great! Can you make...
# 10   Wikipedia   21885  Interesting illustration on the PrIze law page...
# 11   Wikipedia   25456  My concern is that you are proceeding at such ...
# 12   Wikipedia   28354  url' is fooling around with the Rubinstein and...
# ...
